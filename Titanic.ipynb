# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Intern task/titanic_dataset_sample.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass         Name     Sex  Age  SibSp  Parch  \
# 0            1         0       1  Passenger_1    male    2      1      1
# 1            2         1       2  Passenger_2  female    3      2      0
# 2            3         0       3  Passenger_3    male    4      0      1
# 3            4         1       1  Passenger_4  female    5      1      0
# 4            5         0       2  Passenger_5    male    6      2      1
#
#   Ticket   Fare Cabin Embarked
# 0   A/23   3.14    C1        S
# 1   A/46   6.28    C2        C
# 2   A/69   9.42    C3        Q
# 3   A/92  12.56    C4        S
# 4  A/115  15.70    C5        C

# %%
df.shape
# Out:
# (500, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  500 non-null    int64
#  1   Survived     500 non-null    int64
#  2   Pclass       500 non-null    int64
#  3   Name         500 non-null    object
#  4   Sex          500 non-null    object
#  5   Age          500 non-null    int64
#  6   SibSp        500 non-null    int64
#  7   Parch        500 non-null    int64
#  8   Ticket       500 non-null    object
#  9   Fare         500 non-null    float64
#  10  Cabin        500 non-null    object
#  11  Embarked     500 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 47.0+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   500.000000  500.000000  500.000000  500.000000  500.000000
# mean    250.500000    0.500000    1.800000   34.920000    1.002000
# std     144.481833    0.500501    0.749081   20.434499    0.816903
# min       1.000000    0.000000    1.000000    1.000000    0.000000
# 25%     125.750000    0.000000    1.000000   17.000000    0.000000
# 50%     250.500000    0.500000    2.000000   35.000000    1.000000
# 75%     375.250000    1.000000    2.000000   53.000000    2.000000
# max     500.000000    1.000000    3.000000   70.000000    2.000000
#
#             Parch        Fare
# count  500.000000  500.000000
# mean     0.500000   98.570000
# std      0.500501   57.070428
# min      0.000000    0.440000
# 25%      0.000000   49.545000
# 50%      0.500000   98.170000
# 75%      1.000000  147.385000
# max      1.000000  199.740000

# %%
df.nunique()
# Out:
# PassengerId    500
# Survived         2
# Pclass           3
# Name           500
# Sex              2
# Age             70
# SibSp            3
# Parch            2
# Ticket         500
# Fare           500
# Cabin           50
# Embarked         3
# dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(df['Age'], kde=True)
plt.title("Age Distribution")
plt.show()

# %%
sns.countplot(x='Pclass', data=df)
plt.title("Passenger Class Count")
plt.show()

# %%
sns.countplot(x='Sex', hue='Survived', data=df)
plt.title("Survival Count by Gender")
plt.show()

# %%
# Survival rate by Passenger Class
sns.countplot(x='Pclass', hue='Survived', data=df)
plt.title("Survival Rate by Class")
plt.show()

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()
